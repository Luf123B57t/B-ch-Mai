# %%
import pandas as pd

# %%
chartevent = pd.read_csv('chartevents.csv', nrows = 10000)
discharge = pd.read_csv('discharge.csv', nrows = 10000)
microbiologyevent = pd.read_csv('microbiologyevents.csv', nrows = 10000)
procedureevent = pd.read_csv('procedureevents.csv', nrows = 10000)
radiologyevent = pd.read_csv('radiology_detail.csv', nrows = 10000)

# %%
labevent = pd.read_csv('labevents.csv', nrows = 2000)

# %%
chartevent.head(100)
# Out:
#     subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0     10000032  29079034  39553978       18704.0  2180-07-23 12:36:00
# 1     10000032  29079034  39553978       18704.0  2180-07-23 12:36:00
# 2     10000032  29079034  39553978       18704.0  2180-07-23 12:36:00
# 3     10000032  29079034  39553978       18704.0  2180-07-23 14:00:00
# 4     10000032  29079034  39553978       18704.0  2180-07-23 14:00:00
# ..         ...       ...       ...           ...                  ...
# 95    10000032  29079034  39553978       18704.0  2180-07-23 14:30:00
# 96    10000032  29079034  39553978       18704.0  2180-07-23 14:30:00
# 97    10000032  29079034  39553978       18704.0  2180-07-23 14:30:00
# 98    10000032  29079034  39553978       18704.0  2180-07-23 14:30:00
# 99    10000032  29079034  39553978       18704.0  2180-07-23 14:30:00
#
#               storetime  itemid              value  valuenum  valueuom  \
# ...

# %%
# Lọc các itemid bị trùng (giữ tất cả các dòng trùng)
dup_items = chartevent[chartevent.duplicated(subset='itemid', keep=False)]

dup_items
# Out:
#       subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0       10000032  29079034  39553978       18704.0  2180-07-23 12:36:00
# 1       10000032  29079034  39553978       18704.0  2180-07-23 12:36:00
# 2       10000032  29079034  39553978       18704.0  2180-07-23 12:36:00
# 3       10000032  29079034  39553978       18704.0  2180-07-23 14:00:00
# 4       10000032  29079034  39553978       18704.0  2180-07-23 14:00:00
# ...          ...       ...       ...           ...                  ...
# 9995    10001884  26184834  37510196        6823.0  2131-01-16 03:25:00
# 9996    10001884  26184834  37510196        6823.0  2131-01-16 03:25:00
# 9997    10001884  26184834  37510196        6823.0  2131-01-16 03:25:00
# 9998    10001884  26184834  37510196        6823.0  2131-01-16 04:00:00
# 9999    10001884  26184834  37510196        6823.0  2131-01-16 04:00:00
#
#                 storetime  itemid               value  valuenum valueuom  \
# ...

# %%
chartevent[chartevent['itemid'] == 220210]
# Out:
#       subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 11      10000032  29079034  39553978       18704.0  2180-07-23 14:12:00
# 99      10000032  29079034  39553978       18704.0  2180-07-23 14:30:00
# 165     10000032  29079034  39553978       18704.0  2180-07-23 15:00:00
# 179     10000032  29079034  39553978       18704.0  2180-07-23 16:00:00
# 210     10000032  29079034  39553978       18704.0  2180-07-23 17:00:00
# ...          ...       ...       ...           ...                  ...
# 9665    10001884  26184834  37510196        6823.0  2131-01-15 23:00:00
# 9680    10001884  26184834  37510196        6823.0  2131-01-16 00:00:00
# 9849    10001884  26184834  37510196        6823.0  2131-01-16 01:00:00
# 9942    10001884  26184834  37510196        6823.0  2131-01-16 02:00:00
# 9990    10001884  26184834  37510196        6823.0  2131-01-16 03:00:00
#
#                 storetime  itemid value  valuenum  valueuom  warning
# ...

# %%
discharge.head(100)
# Out:
#            note_id  subject_id   hadm_id note_type  note_seq  \
# 0   10000032-DS-21    10000032  22595853        DS        21
# 1   10000032-DS-22    10000032  22841357        DS        22
# 2   10000032-DS-23    10000032  29079034        DS        23
# 3   10000032-DS-24    10000032  25742920        DS        24
# 4   10000084-DS-17    10000084  23052089        DS        17
# ..             ...         ...       ...       ...       ...
# 95   10002430-DS-7    10002430  26295318        DS         7
# 96  10002443-DS-15    10002443  21329021        DS        15
# 97  10002495-DS-13    10002495  24982426        DS        13
# 98  10002528-DS-17    10002528  23193578        DS        17
# 99  10002528-DS-18    10002528  28605730        DS        18
#
#               charttime            storetime  \
# 0   2180-05-07 00:00:00  2180-05-09 15:26:00
# 1   2180-06-27 00:00:00  2180-07-01 10:15:00
# 2   2180-07-25 00:00:00  2180-07-25 21:42:00
# 3   2180-08-07 00:00:00  2180-08-10 05:43:00
# ...

# %%
microbiologyevent.head(100)
# Out:
#     microevent_id  subject_id  hadm_id  micro_specimen_id order_provider_id  \
# 0               1    10000032      NaN            1304715            P69FQC
# 1               2    10000032      NaN            3342526            P69FQC
# 2               3    10000032      NaN            3910370            P69FQC
# 3               4    10000032      NaN            5401234            P69FQC
# 4               5    10000032      NaN            6287540            P69FQC
# ..            ...         ...      ...                ...               ...
# 95             96    10000635      NaN            3803904               NaN
# 96             97    10000650      NaN            9604733               NaN
# 97             98    10000690      NaN            2595393            P25B6Q
# 98             99    10000690      NaN            2595393            P25B6Q
# 99            100    10000690      NaN            2595393            P25B6Q
#
# ...

# %%
procedureevent.head(100)
# Out:
#     subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0     10000032  29079034  39553978       18704.0  2180-07-23 14:43:00
# 1     10000032  29079034  39553978           NaN  2180-07-23 14:24:00
# 2     10000032  29079034  39553978           NaN  2180-07-23 14:24:00
# 3     10000690  25860671  37081114       17393.0  2150-11-02 20:00:00
# 4     10000690  25860671  37081114       17393.0  2150-11-02 20:38:00
# ..         ...       ...       ...           ...                  ...
# 95    10002428  23473524  35479615       31884.0  2156-05-11 17:51:00
# 96    10002428  23473524  35479615       31884.0  2156-05-11 17:51:00
# 97    10002428  23473524  35479615       31884.0  2156-05-11 17:52:00
# 98    10002428  23473524  35479615       31884.0  2156-05-11 17:52:00
# 99    10002428  23473524  35479615       31884.0  2156-05-11 19:19:00
#
#                 endtime                storetime  itemid   value valueuom  \
# ...

# %%
labevent.head(100)
# Out:
#     labevent_id  subject_id  hadm_id  specimen_id  itemid order_provider_id  \
# 0             1    10000032      NaN      2704548   50931            P69FQC
# 1             2    10000032      NaN     36092842   51071            P69FQC
# 2             3    10000032      NaN     36092842   51074            P69FQC
# 3             4    10000032      NaN     36092842   51075            P69FQC
# 4             5    10000032      NaN     36092842   51079            P69FQC
# ..          ...         ...      ...          ...     ...               ...
# 95           96    10000032      NaN     95700408   50861               NaN
# 96           97    10000032      NaN     95700408   50862               NaN
# 97           98    10000032      NaN     95700408   50863               NaN
# 98           99    10000032      NaN     95700408   50868               NaN
# 99          100    10000032      NaN     95700408   50878               NaN
#
# ...

# %%
radiologyevent.head(100)
# Out:
#            note_id  subject_id field_name                  field_value  \
# 0   10000032-RR-14    10000032  exam_code                          C11
# 1   10000032-RR-14    10000032  exam_name             CHEST (PA & LAT)
# 2   10000032-RR-15    10000032  exam_code                         U314
# 3   10000032-RR-15    10000032  exam_code                         U644
# 4   10000032-RR-15    10000032  exam_code                          W82
# ..             ...         ...        ...                          ...
# 95  10000117-RR-25    10000117  exam_code                        E212L
# 96  10000117-RR-25    10000117  exam_name  HIP UNILAT MIN 2 VIEWS LEFT
# 97  10000117-RR-26    10000117  exam_code                        E212L
# 98  10000117-RR-26    10000117  exam_name  HIP UNILAT MIN 2 VIEWS LEFT
# 99  10000117-RR-27    10000117  exam_code                        E212L
#
#     field_ordinal
# 0               1
# 1               1
# 2               1
# 3               3
# ...

# %%
print(chartevent.columns)
# Out:
# Index(['subject_id', 'hadm_id', 'stay_id', 'caregiver_id', 'charttime',
#        'storetime', 'itemid', 'value', 'valuenum', 'valueuom', 'warning'],
#       dtype='object')

# %%
print(discharge.columns)
# Out:
# Index(['note_id', 'subject_id', 'hadm_id', 'note_type', 'note_seq',
#        'charttime', 'storetime', 'text'],
#       dtype='object')

# %%
print(labevent.columns)
# Out:
# Index(['labevent_id', 'subject_id', 'hadm_id', 'specimen_id', 'itemid',
#        'order_provider_id', 'charttime', 'storetime', 'value', 'valuenum',
#        'valueuom', 'ref_range_lower', 'ref_range_upper', 'flag', 'priority',
#        'comments'],
#       dtype='object')

# %%
print(microbiologyevent.columns)
# Out:
# Index(['microevent_id', 'subject_id', 'hadm_id', 'micro_specimen_id',
#        'order_provider_id', 'chartdate', 'charttime', 'spec_itemid',
#        'spec_type_desc', 'test_seq', 'storedate', 'storetime', 'test_itemid',
#        'test_name', 'org_itemid', 'org_name', 'isolate_num', 'quantity',
#        'ab_itemid', 'ab_name', 'dilution_text', 'dilution_comparison',
#        'dilution_value', 'interpretation', 'comments'],
#       dtype='object')

# %%
print(procedureevent.columns)
# Out:
# Index(['subject_id', 'hadm_id', 'stay_id', 'caregiver_id', 'starttime',
#        'endtime', 'storetime', 'itemid', 'value', 'valueuom', 'location',
#        'locationcategory', 'orderid', 'linkorderid', 'ordercategoryname',
#        'ordercategorydescription', 'patientweight', 'isopenbag',
#        'continueinnextdept', 'statusdescription', 'originalamount',
#        'originalrate'],
#       dtype='object')

# %%
print(radiologyevent.columns)
# Out:
# Index(['note_id', 'subject_id', 'field_name', 'field_value', 'field_ordinal'], dtype='object')

# %%
import pandas as pd

mapping_rows = [
    # ===== CHARTEVENTS =====
    {
        "variable_name": "Nhiệt độ",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223761,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "valuenum",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Nhiệt độ",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223762,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "valuenum",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Ho",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223991,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Ho",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223992,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Đờm mủ",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 224370,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Nhịp thở",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 230042,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "valuenum",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "SpO2",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 220277,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "valuenum",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Cần hỗ trợ oxy",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 226732,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "FiO2",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223835,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "valuenum",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Rale",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223986,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Rale",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223987,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Rale",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223988,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Rale",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223989,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Tiếng thở phế quản",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223986,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Tiếng thở phế quản",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223987,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Tiếng thở phế quản",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223988,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Tiếng thở phế quản",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 223989,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Huyết áp tâm thu",
        "source_table": "chartevents",
        "lookup_column": "itemid",
        "lookup_value": 220179,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "valuenum",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },

    # ===== LABEVENTS =====
    {
        "variable_name": "Bạch cầu niệu",
        "source_table": "labevents",
        "lookup_column": "itemid",
        "lookup_value": 51516,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "valuenum",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },
    {
        "variable_name": "Mủ niệu",
        "source_table": "labevents",
        "lookup_column": "itemid",
        "lookup_value": 51516,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "valuenum",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },
    {
        "variable_name": "Nitrat niệu",
        "source_table": "labevents",
        "lookup_column": "itemid",
        "lookup_value": 51987,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },
    {
        "variable_name": "Nitrat niệu",
        "source_table": "labevents",
        "lookup_column": "itemid",
        "lookup_value": 51487,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },

    # ===== MICROBIOLOGY =====
    {
        "variable_name": "Cấy dịch đường hô hấp",
        "source_table": "microbiology",
        "lookup_column": "spec_type_desc",
        "lookup_value": "BRONCHIAL WASHINGS",
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "org_name",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },
    {
        "variable_name": "Cấy dịch đường hô hấp",
        "source_table": "microbiology",
        "lookup_column": "spec_type_desc",
        "lookup_value": "BRONCHOALVEOLAR LAVAGE",
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "org_name",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },
    {
        "variable_name": "Cấy dịch đường hô hấp",
        "source_table": "microbiology",
        "lookup_column": "spec_type_desc",
        "lookup_value": "PLEURAL FLUID",
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "org_name",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },
    {
        "variable_name": "Cấy dịch đường hô hấp",
        "source_table": "microbiology",
        "lookup_column": "spec_type_desc",
        "lookup_value": "SPUTUM",
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "org_name",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },
    {
        "variable_name": "Cấy máu",
        "source_table": "microbiology",
        "lookup_column": "spec_type_desc",
        "lookup_value": "BLOOD CULTURE",
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "org_name",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },
    {
        "variable_name": "Cấy nước tiểu",
        "source_table": "microbiology",
        "lookup_column": "spec_type_desc",
        "lookup_value": "URINE",
        "lookup_operator": "==",
        "secondary_lookup_column": "test_name",
        "secondary_lookup_value": "URINE CULTURE",
        "value_column": "org_name",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": None,
    },

    # ===== PROCEDUREEVENTS =====
    {
        "variable_name": "Thời gian thở máy",
        "source_table": "procedureevents",
        "lookup_column": "itemid",
        "lookup_value": 225792,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "starttime",
        "endtime_column": "endtime",
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Thời gian đặt catheter TMTT",
        "source_table": "procedureevents",
        "lookup_column": "location",
        "lookup_value": "__CENTRAL_LINE__",
        "lookup_operator": "in_list",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "starttime",
        "endtime_column": "endtime",
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },
    {
        "variable_name": "Thời gian đặt ống thông tiểu",
        "source_table": "procedureevents",
        "lookup_column": "itemid",
        "lookup_value": 229351,
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "value",
        "time_column": "starttime",
        "endtime_column": "endtime",
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": "stay_id",
        "note_id_column": None,
    },

    # ===== DISCHARGE =====
    {
        "variable_name": "Ớn lạnh",
        "source_table": "discharge",
        "lookup_column": None,
        "lookup_value": None,
        "lookup_operator": "keyword_search",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "text",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": "note_id",
    },
    {
        "variable_name": "Tiểu gấp",
        "source_table": "discharge",
        "lookup_column": None,
        "lookup_value": None,
        "lookup_operator": "keyword_search",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "text",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": "note_id",
    },
    {
        "variable_name": "Tiểu nhiều lần",
        "source_table": "discharge",
        "lookup_column": None,
        "lookup_value": None,
        "lookup_operator": "keyword_search",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "text",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": "note_id",
    },
    {
        "variable_name": "Tiểu buốt",
        "source_table": "discharge",
        "lookup_column": None,
        "lookup_value": None,
        "lookup_operator": "keyword_search",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "text",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": "note_id",
    },
    {
        "variable_name": "Đau hông sườn",
        "source_table": "discharge",
        "lookup_column": None,
        "lookup_value": None,
        "lookup_operator": "keyword_search",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "text",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": "note_id",
    },
    {
        "variable_name": "Đau/ấn đau vùng trên xương mu",
        "source_table": "discharge",
        "lookup_column": None,
        "lookup_value": None,
        "lookup_operator": "keyword_search",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "text",
        "time_column": "charttime",
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": "hadm_id",
        "stay_id_column": None,
        "note_id_column": "note_id",
    },

    # ===== RADIOLOGY =====
    {
        "variable_name": "X-quang ngực",
        "source_table": "radiology",
        "lookup_column": "field_name",
        "lookup_value": "FINDINGS",
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "field_value",
        "time_column": None,
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": None,
        "stay_id_column": None,
        "note_id_column": "note_id",
    },
    {
        "variable_name": "CT scan lồng ngực",
        "source_table": "radiology",
        "lookup_column": "field_name",
        "lookup_value": "FINDINGS",
        "lookup_operator": "==",
        "secondary_lookup_column": None,
        "secondary_lookup_value": None,
        "value_column": "field_value",
        "time_column": None,
        "endtime_column": None,
        "subject_id_column": "subject_id",
        "hadm_id_column": None,
        "stay_id_column": None,
        "note_id_column": "note_id",
    },
]

variable_mapping = pd.DataFrame(mapping_rows)

variable_mapping = variable_mapping.drop_duplicates(
    subset=[
        "variable_name",
        "source_table",
        "lookup_column",
        "lookup_value",
        "lookup_operator",
        "secondary_lookup_column",
        "secondary_lookup_value",
        "value_column",
        "time_column",
        "endtime_column",
        "subject_id_column",
        "hadm_id_column",
        "stay_id_column",
        "note_id_column",
    ]
).reset_index(drop=True)

# %%
table_map = {
    "chartevents": chartevent,
    "discharge": discharge,
    "labevents": labevent,
    "microbiology": microbiologyevent,
    "procedureevents": procedureevent,
    "radiology": radiologyevent,
}

keyword_map = {
    "Ớn lạnh": ["chills", "rigors", "shivering", "feeling cold", "cold"],
    "Tiểu gấp": ["urinary urgency", "urgency"],
    "Tiểu nhiều lần": ["urinary frequency", "frequent urination"],
    "Tiểu buốt": ["dysuria", "painful urination", "burning on urination"],
    "Đau hông sườn": ["flank pain", "cva tenderness"],
    "Đau/ấn đau vùng trên xương mu": ["suprapubic pain", "suprapubic tenderness"],
}

central_line_locations = [
    "Left IJ", "Right IJ",
    "Left Subclavian", "Right Subclavian",
    "Left Femoral", "Left Femoral.",
    "Right Femoral", "Right Femoral."
]

def get_variable_data(variable_name, subject_id=None, hadm_id=None, stay_id=None):
    mapping = variable_mapping[
        variable_mapping["variable_name"] == variable_name
    ].copy()

    results = []

    for _, row in mapping.iterrows():
        df = table_map[row["source_table"]].copy()

        if subject_id is not None and row["subject_id_column"] in df.columns:
            df = df[df[row["subject_id_column"]] == subject_id]

        if hadm_id is not None and row["hadm_id_column"] is not None and row["hadm_id_column"] in df.columns:
            df = df[df[row["hadm_id_column"]] == hadm_id]

        if stay_id is not None and row["stay_id_column"] is not None and row["stay_id_column"] in df.columns:
            df = df[df[row["stay_id_column"]] == stay_id]

        if row["lookup_operator"] == "==" and row["lookup_column"] is not None:
            df = df[df[row["lookup_column"]] == row["lookup_value"]]

        elif row["lookup_operator"] == "in_list":
            if row["lookup_column"] == "location" and row["lookup_value"] == "__CENTRAL_LINE__":
                df = df[df["location"].isin(central_line_locations)]

        elif row["lookup_operator"] == "keyword_search":
            keywords = keyword_map.get(variable_name, [])
            if "text" in df.columns and keywords:
                pattern = "|".join(keywords)
                df = df[df["text"].str.contains(pattern, case=False, na=False, regex=True)]

        if row["secondary_lookup_column"] is not None:
            col2 = row["secondary_lookup_column"]
            val2 = row["secondary_lookup_value"]
            if col2 in df.columns:
                df = df[df[col2] == val2]

        df = df.copy()
        df["mapped_variable_name"] = row["variable_name"]
        df["mapped_source_table"] = row["source_table"]
        df["mapped_value_column"] = row["value_column"]
        df["mapped_time_column"] = row["time_column"]
        df["mapped_endtime_column"] = row["endtime_column"]

        results.append(df)

    if not results:
        return pd.DataFrame()

    result = pd.concat(results, ignore_index=True, sort=False)
    result = result.drop_duplicates().reset_index(drop=True)
    return result

# %%
get_variable_data("Nhiệt độ", subject_id=10001217)
# Out:
#     subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0     10001217  24597018  37067082       30641.0  2157-11-20 19:31:00
# 1     10001217  24597018  37067082       30641.0  2157-11-20 22:00:00
# 2     10001217  24597018  37067082       30641.0  2157-11-21 04:00:00
# 3     10001217  24597018  37067082       30678.0  2157-11-21 19:00:00
# 4     10001217  24597018  37067082       30678.0  2157-11-21 21:00:00
# 5     10001217  24597018  37067082       40333.0  2157-11-21 00:00:00
# 6     10001217  24597018  37067082       93720.0  2157-11-21 08:00:00
# 7     10001217  24597018  37067082       93720.0  2157-11-21 12:00:00
# 8     10001217  24597018  37067082       93720.0  2157-11-21 16:00:00
# 9     10001217  27703517  34592300       68375.0  2157-12-20 08:00:00
# 10    10001217  27703517  34592300       68375.0  2157-12-20 12:00:00
# 11    10001217  27703517  34592300       73184.0  2157-12-19 20:00:00
# ...

# %%
import pandas as pd
import numpy as np

# =========================
# 1) Helper
# =========================
def _to_datetime_safe(s):
    return pd.to_datetime(s, errors="coerce")

def _contains_any(series, keywords):
    pattern = "|".join(keywords)
    return series.astype(str).str.contains(pattern, case=False, na=False, regex=True)

# =========================
# 2) VAP check for one subject
# =========================
def check_vap_subject(subject_id, verbose=True):
    # ---------- A. Chartevents ----------
    ce = chartevent[chartevent["subject_id"] == subject_id].copy()
    if not ce.empty:
        ce["charttime"] = _to_datetime_safe(ce["charttime"])

    # Nhiệt độ > 38C
    temp_c = ce[(ce["itemid"] == 223762) & (ce["valuenum"] > 38)].copy()

    # Ho: Cough Effort weak/strong
    cough = ce[
        (ce["itemid"] == 223991) &
        (ce["value"].astype(str).str.lower().isin(["weak", "strong"]))
    ].copy()

    # Đờm mủ: Sputum Color != Clear
    sputum = ce[
        (ce["itemid"] == 224370) &
        (~ce["value"].astype(str).str.lower().eq("clear"))
    ].copy()

    # Nhịp thở > 20
    rr = ce[(ce["itemid"] == 230042) & (ce["valuenum"] > 20)].copy()

    # SpO2 < 94
    spo2 = ce[(ce["itemid"] == 220277) & (ce["valuenum"] < 94)].copy()

    # Có hỗ trợ oxy: O2 Delivery Device != none
    oxygen_support = ce[
        (ce["itemid"] == 226732) &
        (~ce["value"].astype(str).str.lower().eq("none"))
    ].copy()

    # Rale / ran / âm phổi bất thường
    lung_sound_keywords = [
        "bronchial", "crackles", "diminished",
        "exp wheeze", "ins/exp wheeze", "insp wheeze",
        "rhonchi", "tubular"
    ]
    lung_sounds = ce[
        ce["itemid"].isin([223986, 223987, 223988, 223989]) &
        _contains_any(ce["value"], lung_sound_keywords)
    ].copy()

    # ---------- B. Radiology ----------
    rad = radiologyevent[radiologyevent["subject_id"] == subject_id].copy()
    pneumonia_keywords = [
        "pneumonia", "pna", "bronchopneumonia", "consolidation",
        "infiltrate", "infiltration", "opacity", "opacities",
        "ground glass", "ggo", "air bronchogram", "patchy",
        "cloudy", "hazy"
    ]
    if not rad.empty:
        imaging = rad[
            (rad["field_name"].astype(str).str.upper() == "FINDINGS") &
            _contains_any(rad["field_value"], pneumonia_keywords)
        ].copy()
    else:
        imaging = pd.DataFrame()

    # ---------- C. Microbiology ----------
    micro = microbiologyevent[microbiologyevent["subject_id"] == subject_id].copy()
    if not micro.empty:
        micro["charttime"] = _to_datetime_safe(micro["charttime"])

    resp_specimens = [
        "BRONCHIAL WASHINGS",
        "BRONCHOALVEOLAR LAVAGE",
        "PLEURAL FLUID",
        "SPUTUM"
    ]

    resp_culture = micro[
        micro["spec_type_desc"].astype(str).isin(resp_specimens) &
        micro["org_name"].notna()
    ].copy()

    blood_culture = micro[
        micro["spec_type_desc"].astype(str).eq("BLOOD CULTURE") &
        micro["org_name"].notna()
    ].copy()

    # ---------- D. Procedureevents: thở máy ----------
    proc = procedureevent[procedureevent["subject_id"] == subject_id].copy()
    if not proc.empty:
        proc["starttime"] = _to_datetime_safe(proc["starttime"])
        proc["endtime"] = _to_datetime_safe(proc["endtime"])

    vent = proc[proc["itemid"] == 225792].copy()

    # =========================
    # 3) Check by stay_id
    # =========================
    stay_ids = sorted(ce["stay_id"].dropna().unique().tolist()) if not ce.empty else []

    results = []

    for stay_id in stay_ids:
        ce_stay = ce[ce["stay_id"] == stay_id].copy()
        hadm_ids = ce_stay["hadm_id"].dropna().unique().tolist()
        hadm_id = hadm_ids[0] if len(hadm_ids) > 0 else np.nan

        temp_stay = temp_c[temp_c["stay_id"] == stay_id]
        cough_stay = cough[cough["stay_id"] == stay_id]
        sputum_stay = sputum[sputum["stay_id"] == stay_id]
        rr_stay = rr[rr["stay_id"] == stay_id]
        spo2_stay = spo2[spo2["stay_id"] == stay_id]
        oxygen_stay = oxygen_support[oxygen_support["stay_id"] == stay_id]
        lung_stay = lung_sounds[lung_sounds["stay_id"] == stay_id]

        # triệu chứng lâm sàng
        symptom_hits = {
            "fever": not temp_stay.empty,
            "cough": not cough_stay.empty,
            "purulent_sputum": not sputum_stay.empty,
            "tachypnea": not rr_stay.empty,
            "low_spo2": not spo2_stay.empty,
            "oxygen_support": not oxygen_stay.empty,
            "abnormal_lung_sounds": not lung_stay.empty,
        }
        symptom_count = sum(symptom_hits.values())

        # imaging theo hadm_id nếu có thể
        # radiology_detail bạn đưa không có hadm_id/time, nên check ở mức subject
        imaging_positive = not imaging.empty

        # microbiology theo hadm_id nếu có
        if not np.isnan(hadm_id):
            resp_culture_stay = resp_culture[resp_culture["hadm_id"] == hadm_id]
            blood_culture_stay = blood_culture[blood_culture["hadm_id"] == hadm_id]
        else:
            resp_culture_stay = resp_culture.iloc[0:0]
            blood_culture_stay = blood_culture.iloc[0:0]

        micro_positive = (not resp_culture_stay.empty) or (not blood_culture_stay.empty)

        # ventilation >= 2 days before first criterion
        positive_event_times = []

        for df_ in [temp_stay, cough_stay, sputum_stay, rr_stay, spo2_stay, oxygen_stay, lung_stay]:
            if not df_.empty and "charttime" in df_.columns:
                positive_event_times.extend(df_["charttime"].dropna().tolist())

        first_criterion_time = min(positive_event_times) if len(positive_event_times) > 0 else pd.NaT

        vent_stay = vent[vent["stay_id"] == stay_id].copy()
        ventilation_ok = False

        if pd.notna(first_criterion_time) and not vent_stay.empty:
            for _, r in vent_stay.iterrows():
                st = r["starttime"]
                if pd.isna(st):
                    continue
                # đặt thở máy trước ít nhất 2 ngày
                if st <= first_criterion_time - pd.Timedelta(days=2):
                    ventilation_ok = True
                    break

        # rule gần đúng:
        # (>=2 triệu chứng) + imaging + ventilation
        # hoặc (>=3 triệu chứng) + ventilation
        vap_flag = (
            ((symptom_count >= 2) and imaging_positive and ventilation_ok) or
            ((symptom_count >= 3) and ventilation_ok) or
            ((symptom_count >= 2) and micro_positive and ventilation_ok)
        )

        results.append({
            "subject_id": subject_id,
            "hadm_id": hadm_id,
            "stay_id": stay_id,
            "symptom_count": symptom_count,
            "fever": symptom_hits["fever"],
            "cough": symptom_hits["cough"],
            "purulent_sputum": symptom_hits["purulent_sputum"],
            "tachypnea": symptom_hits["tachypnea"],
            "low_spo2": symptom_hits["low_spo2"],
            "oxygen_support": symptom_hits["oxygen_support"],
            "abnormal_lung_sounds": symptom_hits["abnormal_lung_sounds"],
            "imaging_positive": imaging_positive,
            "resp_culture_positive": not resp_culture_stay.empty,
            "blood_culture_positive": not blood_culture_stay.empty,
            "ventilation_ok_ge_2d_before_first_criterion": ventilation_ok,
            "first_criterion_time": first_criterion_time,
            "vap_suspected": vap_flag,
        })

    result_df = pd.DataFrame(results).sort_values(["stay_id"])

    if verbose:
        print("=== VAP check ===")
        print(result_df)

    return result_df

# %%
vap_result = check_vap_subject(10000690)
# Out:
# === VAP check ===
#    subject_id   hadm_id   stay_id  symptom_count  fever  cough  \
# 0    10000690  25860671  37081114              5  False   True
#
#    purulent_sputum  tachypnea  low_spo2  oxygen_support  abnormal_lung_sounds  \
# 0             True      False      True            True                  True
#
#    imaging_positive  resp_culture_positive  blood_culture_positive  \
# 0             False                  False                   False
#
#    ventilation_ok_ge_2d_before_first_criterion first_criterion_time  \
# 0                                        False  2150-11-02 19:40:00
#
#    vap_suspected
# 0          False

# %%
chartevent[chartevent['subject_id'] == 10001217]
# Out:
#       subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 4777    10001217  24597018  37067082       30641.0  2157-11-20 19:17:00
# 4778    10001217  24597018  37067082       30641.0  2157-11-20 19:19:00
# 4779    10001217  24597018  37067082       30641.0  2157-11-20 19:19:00
# 4780    10001217  24597018  37067082       30641.0  2157-11-20 19:19:00
# 4781    10001217  24597018  37067082       30641.0  2157-11-20 19:19:00
# ...          ...       ...       ...           ...                  ...
# 7396    10001217  27703517  34592300           NaN  2157-12-20 01:45:00
# 7397    10001217  27703517  34592300           NaN  2157-12-20 01:45:00
# 7398    10001217  27703517  34592300           NaN  2157-12-20 01:45:00
# 7399    10001217  27703517  34592300           NaN  2157-12-20 01:45:00
# 7400    10001217  27703517  34592300           NaN  2157-12-20 01:45:00
#
#                 storetime  itemid value  valuenum valueuom  warning
# ...
